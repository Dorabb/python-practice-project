# %% [markdown]
# <a href="https://colab.research.google.com/github/Dorabb/python-practice-project/blob/main/train_svc_model_plot_dbs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hellow World!!!")
